# %%
from nlinec import get_negative_data, get_positive_data
import numpy as np
import pandas as pd

# %%
positive_data = get_positive_data('augmented_train.json', explode=True)
positive_data
# Out:
# Loading augmented_train.json: 793487it [00:14, 55432.46it/s]
#                  full_type                                       mention_span  \
# 0                   /other  the history and science of aviation and spacef...
# 1                   /other                                          his debut
# 2        /location/country                                                 We
# 3                /location                                                 We
# 4                   /other                                           antibody
# ...                    ...                                                ...
# 1865003    /other/art/film                                          his films
# 1865004             /other                                          his films
# 1865005         /other/art                                          his films
# 1865006         /other/art  Japanese martial arts classes such as Aikido ,...
# 1865007             /other  Japanese martial arts classes such as Aikido ,...
#
#                                                   sentence  granularity  label
# 0        Located in Washington, D.C., United States, it...            1      2
# 1        The seventh child of the Jackson family, he ma...            1      2
# 2                     We did not do anything at that time.            2      2
# 3                     We did not do anything at that time.            1      2
# 4        `` We don't know the effect of our antibody on...            1      2
# ...                                                    ...          ...    ...
# 1865003  As a boy, he donated his Bar Mitzvah money to ...            3      2
# 1865004  As a boy, he donated his Bar Mitzvah money to ...            1      2
# 1865005  As a boy, he donated his Bar Mitzvah money to ...            2      2
# 1865006  Sensei is often used to address the teacher in...            2      2
# 1865007  Sensei is often used to address the teacher in...            1      2
#
# [1865008 rows x 5 columns]

# %%
negative_data = get_negative_data(random_state=42)
negative_data
# Out:
# Loading negative data from /home/psaegert/Projects/nli-nec/src/nlinec/../../data/derived/negative_data/augmented_train.json_42.csv...
#                      full_type  \
# 0                      /person
# 1                    /location
# 2        /organization/transit
# 3                      /person
# 4                /organization
# ...                        ...
# 1865003     /other/product/car
# 1865004          /organization
# 1865005         /location/park
# 1865006          /other/health
# 1865007              /location
#
#                                               mention_span  \
# 0        the history and science of aviation and spacef...
# 1                                                his debut
# 2                                                       We
# 3                                                       We
# 4                                                 antibody
# ...                                                    ...
# 1865003                                          his films
# 1865004                                          his films
# 1865005                                          his films
# 1865006  Japanese martial arts classes such as Aikido ,...
# 1865007  Japanese martial arts classes such as Aikido ,...
#
#                                                   sentence  granularity  label
# 0        Located in Washington, D.C., United States, it...            1      1
# 1        The seventh child of the Jackson family, he ma...            1      1
# 2                     We did not do anything at that time.            2      1
# 3                     We did not do anything at that time.            1      1
# 4        `` We don't know the effect of our antibody on...            1      1
# ...                                                    ...          ...    ...
# 1865003  As a boy, he donated his Bar Mitzvah money to ...            3      1
# 1865004  As a boy, he donated his Bar Mitzvah money to ...            1      1
# 1865005  As a boy, he donated his Bar Mitzvah money to ...            2      1
# 1865006  Sensei is often used to address the teacher in...            2      1
# 1865007  Sensei is often used to address the teacher in...            1      1
#
# [1865008 rows x 5 columns]

# %%
negative_data['full_type'].isna().mean()
# Out:
# 0.004637513619244528

# %%
def combine_positive_negative_data(positive_data: pd.DataFrame, negative_data: pd.DataFrame, frac: float = 0.5, random_state: int = None) -> pd.DataFrame:
    """
    Combine the positive and negative data by randomly replacing a fraction of the positive data with negative data or adding it to the positive data.

    Parameters
    ----------
    positive_data : pd.DataFrame
        The positive data (entailment).
    negative_data : pd.DataFrame
        The negative data (not entailment = neutral).
    frac : float, optional
        The fraction of the positive data that should be replaced with negative data, by default 0.5. If < 0, the negative data is added to the positive data.
    random_state : int, optional
        The random state for the random number generator, by default None

    Returns
    -------
    combined_data : pd.DataFrame
        The combined data.
    """
    if frac > 1:
        raise ValueError(f'frac must be <= 1, but is {frac}')

    if frac < 0:
        return pd.concat([positive_data, negative_data], ignore_index=True)
    
    # Mask for the negative data that has a full_type
    negative_type_available = negative_data['full_type'].notna()

    # Deterministic, random mask for the replacement of the positive data
    if random_state is not None:
        np.random.seed(random_state)
    random_mask = np.random.choice([True, False], size=len(positive_data), p=[frac, frac])

    # Replace the positive data with the negative data
    combined_data = positive_data.copy()
    combined_data.loc[random_mask & negative_type_available, ['full_type', 'label']] = negative_data.loc[random_mask & negative_type_available, ['full_type', 'label']].values

    return combined_data

# %%
combine_positive_negative_data(positive_data, negative_data, frac=0.5, random_state=42)
# Out:
#                  full_type                                       mention_span  \
# 0                  /person  the history and science of aviation and spacef...
# 1                   /other                                          his debut
# 2        /location/country                                                 We
# 3                /location                                                 We
# 4            /organization                                           antibody
# ...                    ...                                                ...
# 1865003    /other/art/film                                          his films
# 1865004             /other                                          his films
# 1865005         /other/art                                          his films
# 1865006      /other/health  Japanese martial arts classes such as Aikido ,...
# 1865007          /location  Japanese martial arts classes such as Aikido ,...
#
#                                                   sentence  granularity  label
# 0        Located in Washington, D.C., United States, it...            1      1
# 1        The seventh child of the Jackson family, he ma...            1      2
# 2                     We did not do anything at that time.            2      2
# 3                     We did not do anything at that time.            1      2
# 4        `` We don't know the effect of our antibody on...            1      1
# ...                                                    ...          ...    ...
# 1865003  As a boy, he donated his Bar Mitzvah money to ...            3      2
# 1865004  As a boy, he donated his Bar Mitzvah money to ...            1      2
# 1865005  As a boy, he donated his Bar Mitzvah money to ...            2      2
# 1865006  Sensei is often used to address the teacher in...            2      1
# 1865007  Sensei is often used to address the teacher in...            1      1
#
# [1865008 rows x 5 columns]

# %%
positive_data['label'].mean()
# Out:
# 1.5020133961891853
